# %%
import requests
import time
import pandas as pd
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

# %%
# driver = webdriver.Edge()
def html_soup(driver,url):
    #here we will add proxies
    
    
#     driver = webdriver.Edge()  # use this when using proxies
    driver.get(url)
    # Allow time for the page to load (you may need to adjust the sleep duration)
    time.sleep(10)

    # Get the updated HTML content after JavaScript has executed
    html_content = driver.page_source

    # Close the WebDriver
#     driver.quit()

    # Now you can use BeautifulSoup to parse the HTML as before
    soup = BeautifulSoup(html_content, 'html.parser')
#     listings_ul = soup.find('ul', class_='hz-Listings hz-Listings--list-view')
#     li = listings_ul.find_all('li')
#     for i in range(len(li)):
#         try:
#             first_link = 'https://www.marktplaats.nl'+li[i].find('a')['href']
#             break
#         except:
#             continue
    return soup

# %%
url = 'https://www.marktplaats.nl/l/auto-s/bestelauto-s/'
soup1 = html_soup(webdriver,url)

# %%
cars = soup1.find_all('div', class_='hz-Filter-attribute')

# %%
len(cars)
# Out:
# 85

# %%
cars[0].text.split('(')[0]
# Out:
# 'Volkswagen'

# %%
models = {}
for i in range(len(cars)):
    try:
        models[str(cars[i].text.split('(')[0])] = str(cars[i].label.a['href'].split('bestelauto-s/')[-1])
        print(cars[i].label.a['href'])
    except:
        pass
# Out:
# /l/auto-s/bestelauto-s/f/volkswagen/595/
# /l/auto-s/bestelauto-s/f/mercedes-benz/593/
# /l/auto-s/bestelauto-s/f/ford/592/
# /l/auto-s/bestelauto-s/f/renault/594/
# /l/auto-s/bestelauto-s/f/opel/599/
# /l/auto-s/bestelauto-s/f/peugeot/600/
# /l/auto-s/bestelauto-s/f/benzine/473/
# /l/auto-s/bestelauto-s/f/diesel/474/
# /l/auto-s/bestelauto-s/f/elektrisch/11756/
# /l/auto-s/bestelauto-s/f/hybride-elektrisch-benzine/13838/
# /l/auto-s/bestelauto-s/f/hybride-elektrisch-diesel/13839/
# /l/auto-s/bestelauto-s/f/lpg/475/
# /l/auto-s/bestelauto-s/f/cng-aardgas/13840/
# /l/auto-s/bestelauto-s/f/overige-brandstoffen/476/
# /l/auto-s/bestelauto-s/

# %%
models
# Out:
# {'Volkswagen': 'f/volkswagen/595/',
#  'Mercedes-Benz': 'f/mercedes-benz/593/',
#  'Ford': 'f/ford/592/',
#  'Renault': 'f/renault/594/',
#  'Opel': 'f/opel/599/',
#  'Peugeot': 'f/peugeot/600/',
#  'Benzine': 'f/benzine/473/',
#  'Diesel': 'f/diesel/474/',
#  'Elektrisch': 'f/elektrisch/11756/',
#  'Hybride Elektrisch/Benzine': 'f/hybride-elektrisch-benzine/13838/',
#  'Hybride Elektrisch/Diesel': 'f/hybride-elektrisch-diesel/13839/',
#  'LPG': 'f/lpg/475/',
#  'CNG ': 'f/cng-aardgas/13840/',
#  'Overige brandstoffen': 'f/overige-brandstoffen/476/',
#  'Altijd': ''}

# %%
car = cars.find_all('li',class_ = 'hz-Level-two')

# %%
soup1
# Out:
# <html lang="nl"><head><meta charset="utf-8"/><meta content="width=device-width, initial-scale=1" name="viewport"/><meta content="app-id=373963365, app-argument=marktplaats://search/execute?categoryId=95&amp;utm_source=smartbanner&amp;utm_medium=smartbanner&amp;utm_content=smartbanner&amp;utm_campaign=smartbanner" name="apple-itunes-app"/><meta content="Koop en verkoop je tweedehands, jong gebruikte of nieuwe Bestelauto's Auto op Marktplaats: de grootste advertentiesite van Nederland." name="description"/><meta content="index, follow" name="robots"/><meta content="1701020025585" name="generation-time-millis"/><link href="https://www.marktplaats.nl/l/auto-s/bestelauto-s/" rel="canonical"/><script async="" src="//cdn.confiant-integrations.net/gptprebidnative/202310231203/wrap.js"></script><script type="application/ld+json">{"@context":"https:\u002F\u002Fschema.org","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"name":"Marktplaats","item":"https:\u002F\u002Fwww.marktplaats.nl\u002F"},{"@type":"ListItem","position":2,"name":"Auto's","item":"https:\u002F\u002Fwww.marktplaats.nl\u002Fl\u002Fauto-s\u002F"},{"@type":"ListItem","position":3,"name":"Bestelauto's","item":"https:\u002F\u002Fwww.marktplaats.nl\u002Fl\u002Fauto-s\u002Fbestelauto-s\u002F"}]}</script><script type="application/ld+json">{"@context":"https:\u002F\u002Fschema.org","@type":"Vehicle","name":"Bestelauto's","model":"","image":"https:\u002F\u002Fimages.marktplaats.com\u002Fapi\u002Fv1\u002Flisting-mp-p\u002Fimages\u002Fd1\u002Fd1393ef1-8830-4e6d-a2a7-0de44b98d9f3?rule=ecg_mp_eps$_82.jpg","brand":{"@type":"Thing","name":""},"offers":{"@type":"AggregateOffer","lowPrice":4500,"highPrice":69900,"priceCurrency":"EUR","availability":"In Stock"}}</script><meta content="9" name="next-head-count"/><meta content="nl" http-equiv="Content-Language"/><link href="//cdn.ebayclassifieds.net/lrp/static/vendor/hz-design-tokens/mp/tokens/CssVars.86b0cf1e.css" rel="stylesheet"/><link href="//cdn.ebayclassifieds.net/lrp/static/vendor/hz-web-ui/mp/assets/Assets.12c061fe.css" rel="stylesheet"/><link href="//cdn.ebayclassifieds.net/lrp/static/vendor/hz-web-ui/mp/Fonts.af97ee0f.css" rel="stylesheet"/><link href="//cdn.ebayclassifieds.net/lrp/static/vendor/hz-web-ui/mp/icons/Icons.2b81d16f.css" rel="stylesheet"/><link href="//cdn.ebayclassifieds.net/lrp/static/vendor/hz-web-ui/mp/Index.3327748f.css" rel="stylesheet"/><link href="//cdn.ebayclassifieds.net/lrp/static/vendor/hz-web-ui/mp/apps/Header/Index.0c91a180.css" rel="stylesheet"/><link href="//cdn.ebayclassifieds.net/lrp/static/vendor/hz-web-ui/mp/apps/LoginNudge/Index.df8664dd.css" rel="stylesheet"/><link href="//cdn.ebayclassifieds.net/lrp/static/vendor/hz-web-ui/mp/favicons/favicon.53911c94.ico" rel="shortcut icon"/><link href="//cdn.ebayclassifieds.net/lrp/static/vendor/hz-web-ui/mp/favicons/apple-touch-icon-57x57.c048cb4e.png" rel="apple-touch-icon" sizes="57x57"/><link href="//cdn.ebayclassifieds.net/lrp/static/vendor/hz-web-ui/mp/favicons/apple-touch-icon-114x114.ea366763.png" rel="apple-touch-icon" sizes="114x114"/><link href="//cdn.ebayclassifieds.net/lrp/static/vendor/hz-web-ui/mp/favicons/apple-touch-icon-72x72.59be38cf.png" rel="apple-touch-icon" sizes="72x72"/><link href="//cdn.ebayclassifieds.net/lrp/static/vendor/hz-web-ui/mp/favicons/apple-touch-icon-144x144.ffaf6f9c.png" rel="apple-touch-icon" sizes="144x144"/><link href="//cdn.ebayclassifieds.net/lrp/static/vendor/hz-web-ui/mp/favicons/apple-touch-icon-60x60.162072b8.png" rel="apple-touch-icon" sizes="60x60"/><link href="//cdn.ebayclassifieds.net/lrp/static/desing-sdk/themes/mp/favicons/apple-touch-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/><link href="//cdn.ebayclassifieds.net/lrp/static/vendor/hz-web-ui/mp/favicons/apple-touch-icon-76x76.cb92b85b.png" rel="apple-touch-icon" sizes="76x76"/><link href="//cdn.ebayclassifieds.net/lrp/static/vendor/hz-web-ui/mp/favicons/apple-touch-icon-152x152.5acb4c1d.png" rel="apple-touch-icon" ...
#     const navigationType = window?.performance?.getEntriesByType('navigation')[0]?.type;
#
#     if (navigationType === 'reload') {
#       window.document.documentElement.classList.add('loading-reload');
#     }
#     window.removeLoadingReloadClass = () => {
#       setTimeout(() => {
#         window.document.documentElement.classList.remove('loading-reload');
#       }, 0);
#     };
#   </script><script type="text/javascript">
#     const isDesktop = window.matchMedia('screen and (min-width: 1024px)').matches;
#     const lcpUrl = isDesktop ? "https://mp.images.icas.io/api/v1/a6519ad0/images/08/0802f774-2aa9-47a3-bf70-df9467a052cc?rule=eps_83" : "https://mp.images.icas.io/api/v1/a6519ad0/images/08/0802f774-2aa9-47a3-bf70-df9467a052cc?rule=eps_82";
#     if (!window.location.hash) {
#       const link = window.document.createElement('link');
#       link.fetchPriority = "high";
#       link.rel = "preload";
#       link.href = lcpUrl;
#       link.as = "image";
#       window.document.head.appendChild(link);
#     }
#   </script><link as="image" fetchpriority="high" href="https://mp.images.icas.io/api/v1/a6519ad0/images/08/0802f774-2aa9-47a3-bf70-df9467a052cc?rule=eps_82" rel="preload"/><script nomodule="" src="//cdn.ebayclassifieds.net/lrp/static/polyfill/sdk/polyfills.js"></script><script nomodule="">
#     if (window.NodeList && !NodeList.prototype.forEach) {
#       NodeList.prototype.forEach = Array.prototype.forEach;
#     }
#   </script><script nomodule="" src="//cdn.ebayclassifieds.net/lrp/static/vendor/ponyfill/css-vars-ponyfill.min.fca7a88a.js"></script><script nomodule="">
#     document.addEventListener("DOMContentLoaded", function () {
#       if (typeof cssVars !== 'undefined') {
#         cssVars({
#           onlyLegacy: true,
#           watch: true
#         });
#       }
#     })
#   </script><script type="text/javascript">
#       (function(h,o,u,n,d) {
#         h=h[d]=h[d]||{q:[],onReady:function(c){h.q.push(c)}}
#         d=o.createElement(u);d.async=1;d.src=n
#         n=o.getElementsByTagName(u)[0];n.parentNode.insertBefore(d,n)
#       })(window,document,'script','https://www.datadoghq-browser-agent.com/datadog-rum-v4.js','DD_RUM')
#       DD_RUM.onReady(function() {
#         DD_RUM.init({
#           clientToken: 'pub9ef3c0e015c96f4f2c04de665a5181b8',
#           applicationId: '466a7b7f-f330-4a8c-8806-b983c9b0dee0',
#           site: 'datadoghq.com',
#           service: 'lrp-web-bff',
#           env: 'production',
#           enableExperimentalFeatures: ['feature_flags'],
#           version: '171cffb7cd331835556d77b8d51dc79f9222bb82',
#           sampleRate: 1,
#           sessionReplaySampleRate: 10,
#           trackResources: true,
#           trackLongTasks: true,
#           trackInteractions: true,
#           defaultPrivacyLevel: 'allow', // allow | mask-user-input | mask
#           allowedTracingOrigins: [
#             'https://www.marktplaats.nl',
#           ],
#           tracingSampleRate: 100,
#         });
#
#         DD_RUM.startSessionReplayRecording();
#
#         DD_RUM.addFeatureFlagEvaluation('BNL19646', 'B');DD_RUM.addFeatureFlagEvaluation('BNL15768', 'B');DD_RUM.addFeatureFlagEvaluation('BNL22430', 'B');
#       })
#     </script><script>function _typeof(t){return(_typeof="function"==typeof Symbol&&"symbol"==typeof Symbol.iterator?function(t){return typeof t}:function(t){return t&&"function"==typeof Symbol&&t.constructor===Symbol&&t!==Symbol.prototype?"symbol":typeof t})(t)}!function(){for(var t,e,o=[],n=window,r=n;r;){try{if(r.frames.__tcfapiLocator){t=r;break}}catch(t){}if(r===n.top)break;r=n.parent}t||(function t(){var e=n.document,o=!!n.frames.__tcfapiLocator;if(!o)if(e.body){var r=e.createElement("iframe");r.style.cssText="display:none",r.name="__tcfapiLocator",e.body.appendChild(r)}else setTimeout(t,5);return!o}(),n.__tcfapi=function(){for(var t=arguments.length,n=new Array(t),r=0;r<t;r++)n[r]=arguments[r];if(!n.length)return o;"setGdprApplies"===n[0]?n.length>3&&2===parseInt(n[1],10)&&"boolean"==typeof n[3]&&(e=n[3],"function"==typeof n[2]&&n[2]("set",!0)):"ping"===n[0]?"function"==typeof n[2]&&n[2]({gdprApplies:e,cmpLoaded:!1,cmpStatus:"stub"}):o.push(n)},n.addEventListener("message",(function(t){var e="string"==typeof t.data,o={};if(e)try{o=JSON.parse(t.data)}catch(t){}else o=t.data;var n="object"===_typeof(o)?o.__tcfapiCall:null;n&&window.__tcfapi(n.command,n.version,(function(o,r){var a={__tcfapiReturn:{returnValue:o,success:r,callId:n.callId}};t&&t.source&&t.source.postMessage&&t.source.postMessage(e?JSON.stringify(a):a,"*")}),n.parameter)}),!1))}();</script><script>
#   window._sp_ss_config = {
#     accountId: 1825,
#     baseEndpoint: 'https://consent.marktplaats.nl',
#     privacyManagerModalId: 659158,
#   };
# </script><script src="//cdn.ebayclassifieds.net/lrp/static/vendor/sourcepoint-lib/index.143df309.js"></script><script async="" src="https://consent.marktplaats.nl/unified/wrapperMessagingWithoutDetection.js"></script><script type="text/javascript">window.dataLayer = [{"s":{"pn":-1,"ps":-1,"tr":-1,"srt":{},"prc":{"mn":-1,"mx":-1}},"l":{"d":0,"pcid":""},"m":{},"p":{"t":"ResultsSearch","lng":"en-US,en;q=0.9","vt":"LR","v":7},"c":{"c":{"id":95,"n":"Bestelauto's"},"l1":{"id":91,"n":"Auto's"},"l2":{"id":95,"n":"Bestelauto's"},"sfc":{"id":91,"n":"auto-s"}},"u":{"li":false,"tg":{"stg":"bnl15048_a|bnl20531_b|bnl19548_b|hzbit1297_a|bnl22430_b|bnl19879_a|bnl15541_c|bnl21671_b|hzbit1566_b|bnl19677_c|bnl22429_b|bnl23274_b|bnl14383_a|bnl12606_b|bnl19562_b|bnl19580_b|bnl305_b|aur10773_twh_b|bnl15938_b|bnl22166_b|bnl20533_b|aur8030_c|bnl13923_b|sentryforecgjsbanners_b|aur10188_a|bnl14010_b|aur13712_b|bnl12937_a|aur11189_b|bnl20605_b|bnl15586_b|hz1509_a|bnl-89_b|bnl4892_b|bnl14236_a|bnl21908_b|bnl23174_b|hz1658_a|bnl6982_b|bnl14558_a|hz2699_b|aur5875_c|aur-cdata673_b|bnl22443_a|aur7918_b|bnl23054_b|bnl15760_b|bnl8457_b|bnl15174_b|bnl19343_b|bnl8391_a|configurablelandingpage_b|bnl19646_b|bnl17779_b|bnl19131_a|aur11517_b|bnl19941_b|bnl7593_b|bnl13199_b|bnl22432_b|bnl15768_b|bnl20248_a|bnl22261_b|bnl22438_b|bnl22164_b|pie-2608-reblaze-challenge-tag_a|bnl23272_b|bnl17361_c|logltrfeatures_b|aur7826_b|bnl15616_b|bnl20740_b|bnl15928_b|bnl18883_b|bnl-14989_b|aur10939_a|hzbit1532_a|bnl6991_b|bnl22271_b|bnl19446_b|aur10773_mp_b|bnl17694_b|aur3186_b|de5522_b|bnl897_b|aur10963_b|bnl20532_b|bnl13133_a|bnl6934_b|bnl14618_a|bnl6999_b|bnl6959_b"}},"d":{"ua":"Mozilla\u002F5.0 (X11; Linux x86_64) AppleWebKit\u002F537.36 (KHTML, like Gecko) Chrome\u002F119.0.0.0 Safari\u002F537.36 Edg\u002F119.0.0.0"},"a":"","o":{}},{"consentToAllPurposes":false},{"consentToAllPurposes":false}]</script><script type="text/javascript">window.ecGaEventsOnLoad = [];
#     window.ecGa = window.ecGa || function() { (ecGa.q = ecGa.q || []).push(arguments) };
#     window.ecGaInitialId = 'UA-4684363-31'</script><script type="text/javascript">window.customGlobalConfig = {"pageViewGrafanaConfig":{"vurl":"ListingResultsPage","enablePageViewGrafanaMetrics":true,"gptBatchMetricsEndpointUrl":"\u002Fmetrics\u002Fdisplays"},"adsenseMetricConfig":{"vurl":"ListingResultsPage","enableAdsenseMetrics":true,"gptBatchMetricsEndpointUrl":"\u002Fmetrics\u002Fdisplays"}}</script><script async="" src="//cdn.ebayclassifieds.net/lrp/static/vendor/ecg-js-ga-tracking/index.5d1d825e.js"></script><script async="" src="//www.google-analytics.com/analytics.js"></script><script type="text/javascript">
#     const STORAGE_SCROLL_KEY = 'lrp_scroll_store';
#     const TYPE_BACK_FORWARD = 2;
#
#     window.addEventListener('pageshow', (event) => {
#       const isNavigatedBack =
#         window?.performance?.getEntriesByType('navigation')?.[0]?.type === 'back_forward' ||
#         window?.performance?.navigation?.type === TYPE_BACK_FORWARD;
#       const isScrolledToTop = window.scrollY === 0;
#       const isScrolledBelowSmartBanner = window.scrollY === 1;
#       const scrollRestorationEvent = {
#         eventAction: 'exposedScrollRestoration',
#       };
#       const storageItem = sessionStorage.getItem(STORAGE_SCROLL_KEY);
#       let parsedStorageItem = {};
#       if (storageItem) {
#         try {
#           parsedStorageItem = JSON.parse(storageItem);
#         } catch (e) {
#           sessionStorage.removeItem(STORAGE_SCROLL_KEY);
#         }
#       }
#       const { href, pos, height } = parsedStorageItem;
#       const samePage = href === window.location.href;
#       const acceptableDiff = window.innerHeight / 2;
#       const diffScrollPositions = Math.abs(pos - window.scrollY);
#
#       if (isNavigatedBack && samePage && pos > 10 && (isScrolledToTop || isScrolledBelowSmartBanner || diffScrollPositions > acceptableDiff)) {
#         if (history.scrollRestoration) {
#           history.scrollRestoration = 'manual';
#         }
#         setTimeout(() => {
#           const layoutElements = document.querySelectorAll('.hz-Page-body, .hz-Page-container--fullHeight');
#           layoutElements.forEach((el) => {
#             el.style.minHeight = height + 'px';
#           });
#           window.scrollTo(0, pos);
#         }, 0);
#       }
#     });
#   </script><script>
#     var pbjs = pbjs || {};
#     pbjs.que = pbjs.que || [];
#   </script><script async="" src="//cdn.ebayclassifieds.net/lrp/static/vendor/aurora-prebid/prebid.a0bee632.js" type="text/javascript"></script><script charset="utf-8" type="text/javascript">(function (G, o, O, g, L, e) { G[g] = G[g] || function () { (G[g]['q'] = G[g]['q'] || []).push(arguments) }, G[g]['t'] = 1 * new Date; })(window, document, 'script', '_googCsa');</script><script defer="" src="/c3650cdf-216a-4ba2-80b0-9d6c540b105e58d2670b-ea0f-484e-b88c-0e2c1499ec9bd71e4b42-8570-44e3-89b6-845326fa43b6"></script><link href="android-app://nl.marktplaats.android/marktplaats/search/execute?categoryId=95&amp;utm_source=google&amp;utm_medium=organic" rel="alternate"/><link as="style" href="/lrp/static/_next/static/css/pages/_app.7b8b1d01.css" rel="preload"/><link data-n-g="" href="/lrp/static/_next/static/css/pages/_app.7b8b1d01.css" rel="stylesheet"/><link as="style" href="/lrp/static/_next/static/css/496.82c75f92.css" rel="preload"/><link data-n-p="" href="/lrp/static/_next/static/css/496.82c75f92.css" rel="stylesheet"/><noscript data-n-css=""></noscript><script defer="" nomodule="" src="/lrp/static/_next/static/chunks/polyfills-c67a75d1b6f99dc8.js"></script><script defer="" src="/lrp/static/_next/static/chunks/webpack-e7324bd9903079f0.js"></script><script defer="" src="/lrp/static/_next/static/chunks/framework-f25fd465f562ee6d.js"></script><script defer="" src="/lrp/static/_next/static/chunks/main-83ec85fdb3517fee.js"></script><script defer="" src="/lrp/static/_next/static/chunks/pages/_app-52040a22e31db1e1.js"></script><script defer="" src="/lrp/static/_next/static/chunks/b1c4d607-06797488172025a6.js"></script><script defer="" src="/lrp/static/_next/static/chunks/816-6ecb6649bf5d48ad.js"></script><script defer="" src="/lrp/static/_next/static/chunks/990-6750aed26b5a4948.js"></script><script defer="" src="/lrp/static/_next/static/chunks/124-becdcc436b6edb41.js"></script><script defer="" src="/lrp/static/_next/static/chunks/496-dc8da2d02027e977.js"></script><script defer="" src="/lrp/static/_next/static/chunks/610-3f0b3fe922f96a49.js"></script><script defer="" src="/lrp/static/_next/static/chunks/pages/lrp.mp.nlnl-5016f5c03a5f4dd7.js"></script><script defer="" src="/lrp/static/_next/static/nHUtvr65kZOmlISLyQuZk/_buildManifest.js"></script><script defer="" src="/lrp/static/_next/static/nHUtvr65kZOmlISLyQuZk/_ssgManifest.js"></script><script charset="utf-8" src="https://consent.marktplaats.nl/unified/4.13.4/gdpr-tcf.29a1390ca5468e08c1ee.bundle.js"></script><title>≥ Occasions en nieuwe Bestelauto's Auto's op Marktplaats</title><script async="" src="https://cdn.confiant-integrations.net/aIj2aGyymun2M_G7bnHGdF9sMf0/gpt_and_prebid/config.js" type="text/javascript"></script><meta content="" http-equiv="origin-trial"/><meta content="" http-equiv="origin-trial"/><meta content="" http-equiv="origin-trial"/><meta content="" http-equiv="origin-trial"/><script async= ...

# %%
import json

# The provided JSON-like structure
json_data = '''
{
  "searchCategoryOptions":[{"fullName":"Auto's","id":91,"key":"auto-s","name":"Auto's"},{"fullName":"Abarth","id":2932,"key":"abarth","name":"Abarth","parentId":91,"parentKey":"auto-s"},{"fullName":"Aiways","id":3217,"key":"aiways","name":"Aiways","parentId":91,"parentKey":"auto-s"},{"fullName":"Aixam","id":2152,"key":"aixam","name":"Aixam","parentId":91,"parentKey":"auto-s"},{"fullName":"Alfa Romeo","id":92,"key":"alfa-romeo","name":"Alfa Romeo","parentId":91,"parentKey":"auto-s"},{"fullName":"Alpina","id":2937,"key":"alpina","name":"Alpina","parentId":91,"parentKey":"auto-s"},{"fullName":"Aston Martin","id":2153,"key":"aston-martin","name":"Aston Martin","parentId":91,"parentKey":"auto-s"},{"fullName":"Alpine","id":2936,"key":"alpine","name":"Alpine","parentId":91,"parentKey":"auto-s"},{"fullName":"Audi","id":93,"key":"audi","name":"Audi","parentId":91,"parentKey":"auto-s"},{"fullName":"Austin","id":2154,"key":"austin","name":"Austin","parentId":91,"parentKey":"auto-s"},{"fullName":"Bentley","id":2148,"key":"bentley","name":"Bentley","parentId":91,"parentKey":"auto-s"},{"fullName":"Bestelauto's","id":95,"key":"bestelauto-s","name":"Bestelauto's","parentId":91,"parentKey":"auto-s"},{"fullName":"BMW","id":96,"key":"bmw","name":"BMW","parentId":91,"parentKey":"auto-s"},{"fullName":"Bugatti","id":2938,"key":"bugatti","name":"Bugatti","parentId":91,"parentKey":"auto-s"},{"fullName":"Buick","id":97,"key":"buick","name":"Buick","parentId":91,"parentKey":"auto-s"},{"fullName":"BYD","id":3213,"key":"byd","name":"BYD","parentId":91,"parentKey":"auto-s"},{"fullName":"Cadillac","id":98,"key":"cadillac","name":"Cadillac","parentId":91,"parentKey":"auto-s"},{"fullName":"Chevrolet","id":99,"key":"chevrolet","name":"Chevrolet","parentId":91,"parentKey":"auto-s"},{"fullName":"Chrysler","id":100,"key":"chrysler","name":"Chrysler","parentId":91,"parentKey":"auto-s"},{"fullName":"Citroën","id":101,"key":"citroen","name":"Citroën","parentId":91,"parentKey":"auto-s"},{"fullName":"Cupra","id":3051,"key":"cupra","name":"Cupra","parentId":91,"parentKey":"auto-s"},{"fullName":"Dacia","id":2660,"key":"dacia","name":"Dacia","parentId":91,"parentKey":"auto-s"},{"fullName":"Daewoo","id":103,"key":"daewoo","name":"Daewoo","parentId":91,"parentKey":"auto-s"},{"fullName":"Daihatsu","id":105,"key":"daihatsu","name":"Daihatsu","parentId":91,"parentKey":"auto-s"},{"fullName":"Dodge","id":108,"key":"dodge","name":"Dodge","parentId":91,"parentKey":"auto-s"},{"fullName":"DS","id":2933,"key":"ds","name":"DS","parentId":91,"parentKey":"auto-s"},{"fullName":"Ferrari","id":110,"key":"ferrari","name":"Ferrari","parentId":91,"parentKey":"auto-s"},{"fullName":"Fiat","id":111,"key":"fiat","name":"Fiat","parentId":91,"parentKey":"auto-s"},{"fullName":"Fisker","id":2829,"key":"fisker","name":"Fisker","parentId":91,"parentKey":"auto-s"},{"fullName":"Ford","id":112,"key":"ford","name":"Ford","parentId":91,"parentKey":"auto-s"},{"fullName":"Ford Usa","id":113,"key":"ford-usa","name":"Ford Usa","parentId":91,"parentKey":"auto-s"},{"fullName":"GMC","id":2949,"key":"gmc","name":"GMC","parentId":91,"parentKey":"auto-s"},{"fullName":"Honda","id":114,"key":"honda","name":"Honda","parentId":91,"parentKey":"auto-s"},{"fullName":"Hummer","id":2149,"key":"hummer","name":"Hummer","parentId":91,"parentKey":"auto-s"},{"fullName":"Hongqi","id":3221,"key":"hongqi","name":"Hongqi","parentId":91,"parentKey":"auto-s"},{"fullName":"Hyundai","id":115,"key":"hyundai","name":"Hyundai","parentId":91,"parentKey":"auto-s"},{"fullName":"Infiniti","id":2659,"key":"infiniti","name":"Infiniti","parentId":91,"parentKey":"auto-s"},{"fullName":"Isuzu","id":3212,"key":"isuzu","name":"Isuzu","parentId":91,"parentKey":"auto-s"},{"fullName":"Jaguar","id":117,"key":"jaguar","name":"Jaguar","parentId":91,"parentKey":"auto-s"},{"fullName":"Jeep","id":118,"key":"jeep","name":"Jeep","parentId":91,"parentKey":"auto-s"},{"fullName":"Kia","id":119,"key":"kia","name":"Kia","parentId":91,"parentKey":"auto-s"},{"fullName":"Lada","id":2155,"key":"lada","name":"Lada","parentId":91,"parentKey":"auto-s"},{"fullName":"Lamborghini","id":122,"key":"lamborghini","name":"Lamborghini","parentId":91,"parentKey":"auto-s"},{"fullName":"Lancia","id":123,"key":"lancia","name":"Lancia","parentId":91,"parentKey":"auto-s"},{"fullName":"Land Rover","id":124,"key":"land-rover","name":"Land Rover","parentId":91,"parentKey":"auto-s"},{"fullName":"Landwind","id":2831,"key":"landwind","name":"Landwind","parentId":91,"parentKey":"auto-s"},{"fullName":"Lexus","id":125,"key":"lexus","name":"Lexus","parentId":91,"parentKey":"auto-s"},{"fullName":"Lincoln","id":2150,"key":"lincoln","name":"Lincoln","parentId":91,"parentKey":"auto-s"},{"fullName":"Lotus","id":127,"key":"lotus","name":"Lotus","parentId":91,"parentKey":"auto-s"},{"fullName":"Lucid","id":3218,"key":"lucid","name":"Lucid","parentId":91,"parentKey":"auto-s"},{"fullName":"Lynk \u0026 Co","id":3211,"key":"lynk-co","name":"Lynk \u0026 Co","parentId":91,"parentKey":"auto-s"},{"fullName":"Maserati","id":128,"key":"maserati","name":"Maserati","parentId":91,"parentKey":"auto-s"},{"fullName":"Mazda","id":129,"key":"mazda","name":"Mazda","parentId":91,"parentKey":"auto-s"},{"fullName":"McLaren","id":2935,"key":"mclaren","name":"McLaren","parentId":91,"parentKey":"auto-s"},{"fullName":"Mercedes-Benz","id":130,"key":"mercedes-benz","name":"Mercedes-Benz","parentId":91,"parentKey":"auto-s"},{"fullName":"Mercury","id":131,"key":"mercury","name":"Mercury","parentId":91,"parentKey":"auto-s"},{"fullName":"MG","id":132,"key":"mg","name":"MG","parentId":91,"parentKey":"auto-s"},{"fullName":"Mini","id":133,"key":"mini","name":"Mini","parentId":91,"parentKey":"auto-s"},{"fullName":"Mitsubishi","id":134,"key":"mitsubishi","name":"Mitsubishi","parentId":91,"parentKey":"auto-s"},{"fullName":"NIO","id":3214,"key":"nio","name":"NIO","parentId":91,"parentKey":"auto-s"},{"fullName":"Nissan","id":135,"key":"nissan","name":"Nissan","parentId":91,"parentKey":"auto-s"},{"fullName":"Oldsmobile","id":136,"key":"oldsmobile","name":"Oldsmobile","parentId":91,"parentKey":"auto-s"},{"fullName":"Oldtimers","id":137,"key":"oldtimers","name":"Oldtimers","parentId":91,"parentKey":"auto-s"},{"fullName":"Opel","id":138,"key":"opel","name":"Opel","parentId":91,"parentKey":"auto-s"},{"fullName":"Peugeot","id":140,"key":"peugeot","name":"Peugeot","parentId":91,"parentKey":"auto-s"},{"fullName":"Polestar","id":2934,"key":"polestar","name":"Polestar","parentId":91,"parentKey":"auto-s"},{"fullName":"Pontiac","id":143,"key":"pontiac","name":"Pontiac","parentId":91,"parentKey":"auto-s"},{"fullName":"Porsche","id":144,"key":"porsche","name":"Porsche","parentId":91,"parentKey":"auto-s"},{"fullName":"RAM","id":3219,"key":"ram","name":"RAM","parentId":91,"parentKey":"auto-s"},{"fullName":"Renault","id":146,"key":"renault","name":"Renault","parentId":91,"parentKey":"auto-s"},{"fullName":"Rolls-Royce","id":2156,"key":"rolls-royce","name":"Rolls-Royce","parentId":91,"parentKey":"auto-s"},{"fullName":"Rover","id":147,"key":"rover","name":"Rover","parentId":91,"parentKey":"auto-s"},{"fullName":"Saab","id":148,"key":"saab","name":"Saab","parentId":91,"parentKey":"auto-s"},{"fullName":"Seat","id":150,"key":"seat","name":"Seat","parentId":91,"parentKey":"auto-s"},{"fullName":"Seres","id":3220,"key":"seres","name":"Seres","parentId":91,"parentKey":"auto-s"},{"fullName":"Skoda","id":151,"key":"skoda","name":"Skoda","parentId":91,"parentKey":"auto-s"},{"fullName":"Smart","id":152,"key":"smart","name":"Smart","parentId":91,"parentKey":"auto-s"},{"fullName":"Spyker","id":2939,"key":"spyker","name":"Spyker","parentId":91,"parentKey":"auto-s"},{"fullName":"SsangYong","id":2151,"key":"ssangyong","name":"SsangYong","parentId":91,"parentKey":"auto-s"},{"fullName":"Subaru","id":153,"key":"subaru","name":"Subaru","parentId":91,"parentKey":"auto-s"},{"fullName":"Suzuki","id":154,"key":"suzuki","name":"Suzuki","parentId":91,"parentKey":"auto-s"},{"fullName":"Tesla","id":2830,"key":"tesla","name":"Tesla","parentId":91,"parentKey":"auto-s"},{"fullName":"Toyota","id":155,"key":"toyota","name":"Toyota","parentId":91,"parentKey":"auto-s"},{"fullName":"Triumph","id":156,"key":"triumph","name":"Triumph","parentId":91,"parentKey":"auto-s"},{"fullName":"Vinfast","id":3216,"key":"vinfast","name":"Vinfast","parentId":91,"parentKey":"auto-s"},{"fullName":"Volkswagen","id":157,"key":"volkswagen","name":"Volkswagen","parentId":91,"parentKey":"auto-s"},{"fullName":"Volvo","id":158,"key":"volvo","name":"Volvo","parentId":91,"parentKey":"auto-s"},{"fullName":"Vrachtwagens","id":159,"key":"vrachtwagens","name":"Vrachtwagens","parentId":91,"parentKey":"auto-s"},{"fullName":"XPENG","id":3215,"key":"xpeng","name":"XPENG","parentId":91,"parentKey":"auto-s"},{"fullName":"Overige Auto's","id":139,"key":"overige-auto-s","name":"Overige Auto's","parentId":91,"parentKey":"auto-s"}]
}
'''

# Load the JSON data
data = json.loads(json_data)

# Extract 'name' and 'key' from each entry
for entry in data.get('searchCategoryOptions', []):
    name = entry.get('name', 'N/A')
    key = entry.get('key', 'N/A')
    print(f" {name}, {key}")
# Out:
#  Auto's, auto-s
#  Abarth, abarth
#  Aiways, aiways
#  Aixam, aixam
#  Alfa Romeo, alfa-romeo
#  Alpina, alpina
#  Aston Martin, aston-martin
#  Alpine, alpine
#  Audi, audi
#  Austin, austin
#  Bentley, bentley
#  Bestelauto's, bestelauto-s
#  BMW, bmw
#  Bugatti, bugatti
#  Buick, buick
#  BYD, byd
#  Cadillac, cadillac
#  Chevrolet, chevrolet
#  Chrysler, chrysler
#  Citroën, citroen
#  Cupra, cupra
#  Dacia, dacia
#  Daewoo, daewoo
#  Daihatsu, daihatsu
#  Dodge, dodge
#  DS, ds
#  Ferrari, ferrari
#  Fiat, fiat
#  Fisker, fisker
#  Ford, ford
#  Ford Usa, ford-usa
#  GMC, gmc
#  Honda, honda
#  Hummer, hummer
#  Hongqi, hongqi
#  Hyundai, hyundai
#  Infiniti, infiniti
#  Isuzu, isuzu
#  Jaguar, jaguar
#  Jeep, jeep
#  Kia, kia
#  Lada, lada
#  Lamborghini, lamborghini
#  Lancia, lancia
#  Land Rover, land-rover
#  Landwind, landwind
#  Lexus, lexus
#  Lincoln, lincoln
#  Lotus, lotus
#  Lucid, lucid
#  Lynk & Co, lynk-co
#  Maserati, maserati
#  Mazda, mazda
#  McLaren, mclaren
#  Mercedes-Benz, mercedes-benz
#  Mercury, mercury
#  MG, mg
#  Mini, mini
#  Mitsubishi, mitsubishi
#  NIO, nio
#  Nissan, nissan
#  Oldsmobile, oldsmobile
#  Oldtimers, oldtimers
#  Opel, opel
#  Peugeot, peugeot
#  Polestar, polestar
#  Pontiac, pontiac
#  Porsche, porsche
#  RAM, ram
#  Renault, renault
#  Rolls-Royce, rolls-royce
#  Rover, rover
#  Saab, saab
#  Seat, seat
#  Seres, seres
#  Skoda, skoda
#  Smart, smart
#  Spyker, spyker
#  SsangYong, ssangyong
#  Subaru, subaru
#  Suzuki, suzuki
#  Tesla, tesla
#  Toyota, toyota
#  Triumph, triumph
#  Vinfast, vinfast
#  Volkswagen, volkswagen
#  Volvo, volvo
#  Vrachtwagens, vrachtwagens
#  XPENG, xpeng
#  Overige Auto's, overige-auto-s

# %%
# Create a dictionary with 'name' as the key and 'key' as the value
name_key_dict = {entry.get('name', 'N/A'): entry.get('key', 'N/A') for entry in data.get('searchCategoryOptions', [])}

# Print the resulting dictionary
print(name_key_dict)
# Out:
# {"Auto's": 'auto-s', 'Abarth': 'abarth', 'Aiways': 'aiways', 'Aixam': 'aixam', 'Alfa Romeo': 'alfa-romeo', 'Alpina': 'alpina', 'Aston Martin': 'aston-martin', 'Alpine': 'alpine', 'Audi': 'audi', 'Austin': 'austin', 'Bentley': 'bentley', "Bestelauto's": 'bestelauto-s', 'BMW': 'bmw', 'Bugatti': 'bugatti', 'Buick': 'buick', 'BYD': 'byd', 'Cadillac': 'cadillac', 'Chevrolet': 'chevrolet', 'Chrysler': 'chrysler', 'Citroën': 'citroen', 'Cupra': 'cupra', 'Dacia': 'dacia', 'Daewoo': 'daewoo', 'Daihatsu': 'daihatsu', 'Dodge': 'dodge', 'DS': 'ds', 'Ferrari': 'ferrari', 'Fiat': 'fiat', 'Fisker': 'fisker', 'Ford': 'ford', 'Ford Usa': 'ford-usa', 'GMC': 'gmc', 'Honda': 'honda', 'Hummer': 'hummer', 'Hongqi': 'hongqi', 'Hyundai': 'hyundai', 'Infiniti': 'infiniti', 'Isuzu': 'isuzu', 'Jaguar': 'jaguar', 'Jeep': 'jeep', 'Kia': 'kia', 'Lada': 'lada', 'Lamborghini': 'lamborghini', 'Lancia': 'lancia', 'Land Rover': 'land-rover', 'Landwind': 'landwind', 'Lexus': 'lexus', 'Lincoln': 'lincoln', 'Lotus': 'lotus', 'Lucid': 'lucid', 'Lynk & Co': 'lynk-co', 'Maserati': 'maserati', 'Mazda': 'mazda', 'McLaren': 'mclaren', 'Mercedes-Benz': 'mercedes-benz', 'Mercury': 'mercury', 'MG': 'mg', 'Mini': 'mini', 'Mitsubishi': 'mitsubishi', 'NIO': 'nio', 'Nissan': 'nissan', 'Oldsmobile': 'oldsmobile', 'Oldtimers': 'oldtimers', 'Opel': 'opel', 'Peugeot': 'peugeot', 'Polestar': 'polestar', 'Pontiac': 'pontiac', 'Porsche': 'porsche', 'RAM': 'ram', 'Renault': 'renault', 'Rolls-Royce': 'rolls-royce', 'Rover': 'rover', 'Saab': 'saab', 'Seat': 'seat', 'Seres': 'seres', 'Skoda': 'skoda', 'Smart': 'smart', 'Spyker': 'spyker', 'SsangYong': 'ssangyong', 'Subaru': 'subaru', 'Suzuki': 'suzuki', 'Tesla': 'tesla', 'Toyota': 'toyota', 'Triumph': 'triumph', 'Vinfast': 'vinfast', 'Volkswagen': 'volkswagen', 'Volvo': 'volvo', 'Vrachtwagens': 'vrachtwagens', 'XPENG': 'xpeng', "Overige Auto's": 'overige-auto-s'}

# %%
name_key_dict["Overige Auto's"]
# Out:
# 'overige-auto-s'

# %%
brands = { 'Abarth': 'abarth', 'Aiways': 'aiways', 'Aixam': 'aixam', 'Alfa Romeo': 'alfa-romeo', 'Alpina': 'alpina', 'Aston Martin': 'aston-martin', 'Alpine': 'alpine', 'Audi': 'audi', 'Austin': 'austin', 'Bentley': 'bentley', "Bestelauto's": 'bestelauto-s', 'BMW': 'bmw', 'Bugatti': 'bugatti', 'Buick': 'buick', 'BYD': 'byd', 'Cadillac': 'cadillac', 'Chevrolet': 'chevrolet', 'Chrysler': 'chrysler', 'Citroën': 'citroen', 'Cupra': 'cupra', 'Dacia': 'dacia', 'Daewoo': 'daewoo', 'Daihatsu': 'daihatsu', 'Dodge': 'dodge', 'DS': 'ds', 'Ferrari': 'ferrari', 'Fiat': 'fiat', 'Fisker': 'fisker', 'Ford': 'ford', 'Ford Usa': 'ford-usa', 'GMC': 'gmc', 'Honda': 'honda', 'Hummer': 'hummer', 'Hongqi': 'hongqi', 'Hyundai': 'hyundai', 'Infiniti': 'infiniti', 'Isuzu': 'isuzu', 'Jaguar': 'jaguar', 'Jeep': 'jeep', 'Kia': 'kia', 'Lada': 'lada', 'Lamborghini': 'lamborghini', 'Lancia': 'lancia', 'Land Rover': 'land-rover', 'Landwind': 'landwind', 'Lexus': 'lexus', 'Lincoln': 'lincoln', 'Lotus': 'lotus', 'Lucid': 'lucid', 'Lynk & Co': 'lynk-co', 'Maserati': 'maserati', 'Mazda': 'mazda', 'McLaren': 'mclaren', 'Mercedes-Benz': 'mercedes-benz', 'Mercury': 'mercury', 'MG': 'mg', 'Mini': 'mini', 'Mitsubishi': 'mitsubishi', 'NIO': 'nio', 'Nissan': 'nissan', 'Oldsmobile': 'oldsmobile', 'Oldtimers': 'oldtimers', 'Opel': 'opel', 'Peugeot': 'peugeot', 'Polestar': 'polestar', 'Pontiac': 'pontiac', 'Porsche': 'porsche', 'RAM': 'ram', 'Renault': 'renault', 'Rolls-Royce': 'rolls-royce', 'Rover': 'rover', 'Saab': 'saab', 'Seat': 'seat', 'Seres': 'seres', 'Skoda': 'skoda', 'Smart': 'smart', 'Spyker': 'spyker', 'SsangYong': 'ssangyong', 'Subaru': 'subaru', 'Suzuki': 'suzuki', 'Tesla': 'tesla', 'Toyota': 'toyota', 'Triumph': 'triumph', 'Vinfast': 'vinfast', 'Volkswagen': 'volkswagen', 'Volvo': 'volvo', 'Vrachtwagens': 'vrachtwagens', 'XPENG': 'xpeng', "Overige Auto's": 'overige-auto-s'}

# %%
webdriver_edge = webdriver.Edge()
models = {}
for name, key in brands.items():
    print(f"{key}")
    url = f'https://www.marktplaats.nl/l/auto-s/{key}/'
    soup2 = html_soup(webdriver_edge,url)
    mo = soup2.find_all('div', class_='hz-Filter-attribute')
    
    for i in range(len(mo)):
        try:
            models[str(mo[i].text.split('(')[0])] = str(mo[i].label.a['href'].split(f'{key}/')[-1])
            print(mo[i].label.a['href'].split(f'{key}/')[-1])
        except:
            pass
    print('---------------------')
#     break
# Out:
# abarth
# f/overige-modellen/11813/
# f/500/11811/
#
# ---------------------
# aiways
# f/u5/13872/
# f/u6/13873/
# f/elektrisch/11756/
#
# ---------------------
# aixam
# f/diesel/474/
# f/elektrisch/11756/
#
# ---------------------
# alfa-romeo
# f/mito/551/
# f/giulietta/552/
# f/stelvio/11651/
# f/159/546/
# f/giulia/10900/
# f/147/537/
# f/benzine/473/
# f/diesel/474/
# f/hybride-elektrisch-benzine/13838/
# f/lpg/475/
# f/overige-brandstoffen/476/
#
# ---------------------
# alpina
# f/b3/11941/
# f/b5/11943/
# f/b4/11942/
# f/b6/11944/
# f/b10/11939/
# f/d3/11948/
#
# ---------------------
# aston-martin
# f/db9/554/
# f/v8-vantage/557/
# f/overige-modellen/558/
# f/dbs/555/
# f/rapide/556/
# f/v12-vanquish/10661/
# f/benzine/473/
#
# ---------------------
# alpine
# f/a110/11937/
#
# ---------------------
# audi
# f/a3/560/
# f/a4/561/
# f/a6/562/
# f/a1/582/
# f/a5/570/
# f/q3/10664/
# f/benzine/473/
# f/diesel/474/
# f/elektrisch/11756/
# f/hybride-elektrisch-benzine/13838/
# f/hybride-elektrisch-diesel/13839/
# f/lpg/475/
# f/cng-aardgas/13840/
# f/overige-brandstoffen/476/
#
# ---------------------
# austin
# f/benzine/473/
#
# ---------------------
# bentley
# f/continental/588/
# f/continental-gtc/11722/
# f/bentayga/11721/
# f/flying-spur/11723/
# f/arnage/585/
# f/mulsanne/590/
# f/benzine/473/
# f/diesel/474/
# f/hybride-elektrisch-benzine/13838/
# f/overige-brandstoffen/476/
#
# ---------------------
# bestelauto-s
# f/volkswagen/595/
# f/mercedes-benz/593/
# f/ford/592/
# f/renault/594/
# f/opel/599/
# f/peugeot/600/
# f/benzine/473/
# f/diesel/474/
# f/elektrisch/11756/
# f/hybride-elektrisch-benzine/13838/
# f/hybride-elektrisch-diesel/13839/
# f/lpg/475/
# f/cng-aardgas/13840/
# f/overige-brandstoffen/476/
#
# ---------------------
# bmw
# f/3-serie/610/
# f/5-serie/611/
# f/1-serie/613/
# f/x5/618/
# f/x1/622/
# f/x3/617/
# f/benzine/473/
# f/diesel/474/
# f/elektrisch/11756/
# f/hybride-elektrisch-benzine/13838/
# f/hybride-elektrisch-diesel/13839/
# f/lpg/475/
# f/overige-brandstoffen/476/
#
# ---------------------
# bugatti
# ---------------------
# buick
# f/enclave/10807/
# f/overige-modellen/10814/
# f/regal/10810/
# f/riviera/10811/
# f/park-avenue/10809/
# f/skylark/10812/
# f/benzine/473/
# f/lpg/475/
#
# ---------------------
# byd
# f/overige-modellen/13857/
# f/han/13855/
# f/tang/13856/
# f/elektrisch/11756/
#
# ---------------------
# cadillac
# f/overige-modellen/631/
# f/cts/624/
# f/escalade/627/
# f/srx/629/
# f/sts/630/
# f/eldorado/625/
# f/benzine/473/
# f/diesel/474/
# f/lpg/475/
# f/overige-brandstoffen/476/
#
# ---------------------
# chevrolet
# f/spark/657/
# f/matiz/641/
# f/aveo/645/
# f/overige-modellen/643/
# f/corvette/636/
# f/kalos/640/
# f/benzine/473/
# f/diesel/474/
# f/hybride-elektrisch-benzine/13838/
# f/lpg/475/
# f/overige-brandstoffen/476/
#
# ---------------------
# chrysler
# f/pt-cruiser/661/
# f/grand-voyager/669/
# f/voyager/663/
# f/pacifica/670/
# f/crossfire/667/
# f/300c/665/
# f/benzine/473/
# f/diesel/474/
# f/hybride-elektrisch-benzine/13838/
# f/lpg/475/
#
# ---------------------
# citroen
# f/c3/679/
# f/c1/685/
# f/c5/673/
# f/c4-grand-picasso/687/
# f/c4/680/
# f/c4-cactus/10925/
# f/benzine/473/
# f/diesel/474/
# f/elektrisch/11756/
# f/hybride-elektrisch-benzine/13838/
# f/hybride-elektrisch-diesel/13839/
# f/lpg/475/
# f/cng-aardgas/13840/
# f/overige-brandstoffen/476/
#
# ---------------------
# cupra
# f/formentor/13228/
# f/leon/13230/
# f/born/13810/
# f/ateca/13227/
# f/overige-modellen/13232/
# f/benzine/473/
# f/elektrisch/11756/
# f/hybride-elektrisch-benzine/13838/
# f/overige-brandstoffen/476/
#
# ---------------------
# dacia
# f/sandero/699/
# f/duster/696/
# f/logan-mcv/698/
# f/sandero-stepway/10687/
# f/spring/13912/
# f/lodgy/10686/
# f/benzine/473/
# f/diesel/474/
# f/elektrisch/11756/
# f/hybride-elektrisch-benzine/13838/
# f/lpg/475/
# f/overige-brandstoffen/476/
#
# ---------------------
# daewoo
# f/kalos/706/
# f/matiz/702/
# f/tacuma/709/
# f/lanos/701/
# f/nubira/704/
# f/lacetti/707/
# f/benzine/473/
# f/diesel/474/
# f/lpg/475/
#
# ---------------------
# daihatsu
# f/cuore/713/
# f/sirion/715/
# f/terios/722/
# f/yrv/724/
# f/materia/720/
# f/trevis/726/
# f/benzine/473/
# f/diesel/474/
# f/overige-brandstoffen/476/
#
# ---------------------
# dodge
# f/ram1500/735/
# f/ram/733/
# f/caliber/727/
# f/overige-modellen/734/
# f/challenger/10688/
# f/charger/728/
# f/benzine/473/
# f/diesel/474/
# f/lpg/475/
# f/overige-brandstoffen/476/
#
# ---------------------
# ds
# f/ds-3/11814/
# f/ds-7/11817/
# f/ds-4/11815/
# f/ds-9/13913/
# f/ds-5/11816/
# f/overige-modellen/11818/
#
# ---------------------
# ferrari
# f/overige-modellen/756/
# f/california/751/
# f/360/746/
# f/458/10709/
# f/f430/753/
# f/599/750/
# f/benzine/473/
# f/diesel/474/
# f/overige-brandstoffen/476/
#
# ---------------------
# fiat
# f/500/767/
# f/panda/758/
# f/500c/11667/
# f/punto/759/
# f/punto-evo/779/
# f/grande-punto/772/
# f/benzine/473/
# f/diesel/474/
# f/elektrisch/11756/
# f/hybride-elektrisch-benzine/13838/
# f/lpg/475/
# f/cng-aardgas/13840/
# f/overige-brandstoffen/476/
#
# ---------------------
# fisker
# f/hybride-elektrisch-benzine/13838/
#
# ---------------------
# ford
# f/focus/784/
# f/fiesta/783/
# f/ka/788/
# f/kuga/794/
# f/c-max/793/
# f/mondeo/785/
# f/benzine/473/
# f/diesel/474/
# f/elektrisch/11756/
# f/hybride-elektrisch-benzine/13838/
# f/lpg/475/
# f/overige-brandstoffen/476/
#
# ---------------------
# ford-usa
# f/f-150/802/
# f/mustang/805/
# f/overige-modellen/809/
# f/explorer/801/
# f/f-250/803/
# f/f-350/804/
# f/benzine/473/
# f/diesel/474/
# f/elektrisch/11756/
# f/lpg/475/
# f/overige-brandstoffen/476/
#
# ---------------------
# gmc
# f/benzine/473/
# f/lpg/475/
# f/overige-brandstoffen/476/
#
# ---------------------
# honda
# f/civic/811/
# f/jazz/819/
# f/cr-v/816/
# f/hr-v/818/
# f/accord/810/
# f/insight/822/
# f/benzine/473/
# f/diesel/474/
# f/elektrisch/11756/
# f/hybride-elektrisch-benzine/13838/
# f/lpg/475/
# f/overige-brandstoffen/476/
#
# ---------------------
# hummer
# f/h2/830/
# f/h3/831/
# f/overige-modellen/832/
# f/h1/829/
# f/benzine/473/
# f/diesel/474/
# f/lpg/475/
# f/overige-brandstoffen/476/
#
# ---------------------
# hongqi
# ---------------------
# hyundai
# f/tucson/850/
# f/i10/844/
# f/kona/11901/
# f/i20/851/
# f/i30/845/
# f/ix35/852/
# f/benzine/473/
# f/diesel/474/
# f/elektrisch/11756/
# f/hybride-elektrisch-benzine/13838/
# f/hybride-elektrisch-diesel/13839/
# f/lpg/475/
# f/waterstof/13841/
# f/overige-brandstoffen/476/
#
# ---------------------
# infiniti
# f/q30/11729/
# f/fx-serie/858/
# f/q50/10909/
# f/m-serie/860/
# f/overige-modellen/862/
# f/g-serie/859/
# f/benzine/473/
# f/diesel/474/
# f/hybride-elektrisch-benzine/13838/
# f/lpg/475/
#
# ---------------------
# isuzu
# f/d-max/13800/
# f/overige-modellen/13862/
# f/benzine/473/
# f/diesel/474/
#
# ---------------------
# jaguar
# f/i-pace/11870/
# f/xj/865/
# f/xf/864/
# f/xk/867/
# f/s-type/863/
# f/f-pace/11677/
# f/benzine/473/
# f/diesel/474/
# f/elektrisch/11756/
# f/hybride-elektrisch-benzine/13838/
# f/lpg/475/
# f/overige-brandstoffen/476/
#
# ---------------------
# jeep
# f/compass/876/
# f/wrangler/874/
# f/renegade/10921/
# f/cherokee/872/
# f/grand-cherokee/873/
# f/overige-modellen/875/
# f/benzine/473/
# f/diesel/474/
# f/elektrisch/11756/
# f/hybride-elektrisch-benzine/13838/
# f/lpg/475/
# f/overige-brandstoffen/476/
#
# ---------------------
# kia
# f/picanto/887/
# f/pro-cee-d/883/
# f/niro/11678/
# f/sportage/892/
# f/rio/889/
# f/stonic/11681/
# f/benzine/473/
# f/diesel/474/
# f/elektrisch/11756/
# f/hybride-elektrisch-benzine/13838/
# f/hybride-elektrisch-diesel/13839/
# f/lpg/475/
# f/overige-brandstoffen/476/
#
# ---------------------
# lada
# f/niva/904/
# f/overige-modellen/906/
# f/2104/10779/
# f/kalina/903/
# f/benzine/473/
# f/lpg/475/
#
# ---------------------
# lamborghini
# f/urus/11907/
# f/huracan/11682/
# f/gallardo/10828/
# f/aventador/10825/
# f/diablo/10827/
# f/overige-modellen/10833/
# f/benzine/473/
#
# ---------------------
# lancia
# f/ypsilon/914/
# f/delta/908/
# f/musa/911/
# f/thema/916/
# f/overige-modellen/915/
# f/thesis/913/
# f/benzine/473/
# f/diesel/474/
# f/hybride-elektrisch-benzine/13838/
#
# ---------------------
# land-rover
# f/range-rover-sport/924/
# f/range-rover-evoque/10737/
# f/range-rover/922/
# f/defender/919/
# f/range-rover-velar/11683/
# f/discovery-sport/11588/
# f/benzine/473/
# f/diesel/474/
# f/hybride-elektrisch-benzine/13838/
# f/hybride-elektrisch-diesel/13839/
# f/lpg/475/
# f/overige-brandstoffen/476/
#
# ---------------------
# landwind
# f/benzine/473/
# f/lpg/475/
#
# ---------------------
# lexus
# f/ct-h/932/
# f/rx-h/929/
# f/is/927/
# f/nx/11589/
# f/ux/11902/
# f/gs-h/926/
# f/benzine/473/
# f/diesel/474/
# f/elektrisch/11756/
# f/hybride-elektrisch-benzine/13838/
# f/lpg/475/
# f/overige-brandstoffen/476/
#
# ---------------------
# lincoln
# f/continental/933/
# f/town-car/935/
# f/overige-modellen/936/
# f/navigator/934/
# f/aviator/10740/
# f/mark/10742/
# f/benzine/473/
# f/lpg/475/
# f/waterstof/13841/
# f/overige-brandstoffen/476/
#
# ---------------------
# lotus
# f/elise/10817/
# f/elan/10816/
# f/europa/10820/
# f/super-seven/10823/
# f/overige-modellen/10824/
# f/benzine/473/
#
# ---------------------
# lucid
# ---------------------
# lynk-co
# f/01/13767/
# f/overige-modellen/13863/
# f/benzine/473/
# f/hybride-elektrisch-benzine/13838/
# f/overige-brandstoffen/476/
#
# ---------------------
# maserati
# f/quattroporte/940/
# f/ghibli/938/
# f/levante/11686/
# f/granturismo/939/
# f/overige-modellen/941/
# f/coupe/937/
# f/benzine/473/
# f/diesel/474/
# f/hybride-elektrisch-benzine/13838/
# f/lpg/475/
#
# ---------------------
# mazda
# f/cx-5/10750/
# f/2/952/
# f/3/946/
# f/cx-3/11599/
# f/mx-5/945/
# f/6/947/
# f/benzine/473/
# f/diesel/474/
# f/elektrisch/11756/
# f/hybride-elektrisch-benzine/13838/
# f/lpg/475/
# f/overige-brandstoffen/476/
#
# ---------------------
# mclaren
# f/gt/11931/
# f/570s/11925/
# f/650s/11927/
# f/540c/11923/
# f/570gt/11924/
# f/720s/11929/
#
# ---------------------
# mercedes-benz
# f/c-klasse/965/
# f/a-klasse/964/
# f/e-klasse/966/
# f/cla/10886/
# f/b-klasse/973/
# f/glc/11690/
# f/benzine/473/
# f/diesel/474/
# f/elektrisch/11756/
# f/hybride-elektrisch-benzine/13838/
# f/hybride-elektrisch-diesel/13839/
# f/lpg/475/
# f/cng-aardgas/13840/
# f/overige-brandstoffen/476/
#
# ---------------------
# mercury
# f/overige-modellen/10840/
# f/capri/10834/
# f/grand-marquis/10835/
# f/benzine/473/
# f/hybride-elektrisch-benzine/13838/
# f/lpg/475/
#
# ---------------------
# mg
# f/zs/991/
# f/ehs/13805/
# f/mg4/13830/
# f/mg5/13803/
# f/b/983/
# f/f/985/
# f/benzine/473/
# f/diesel/474/
# f/elektrisch/11756/
# f/hybride-elektrisch-benzine/13838/
# f/overige-brandstoffen/476/
#
# ---------------------
# mini
# f/cooper/995/
# f/countryman/1001/
# f/clubman/1000/
# f/one/997/
# f/cabrio/999/
# f/cooper-s/13787/
# f/benzine/473/
# f/diesel/474/
# f/elektrisch/11756/
# f/hybride-elektrisch-benzine/13838/
# f/overige-brandstoffen/476/
#
# ---------------------
# mitsubishi
# f/outlander/1013/
# f/space-star/1005/
# f/colt/1003/
# f/asx/1016/
# f/eclipse-cross/11966/
# f/grandis/1012/
# f/benzine/473/
# f/diesel/474/
# f/hybride-elektrisch-benzine/13838/
# f/lpg/475/
# f/overige-brandstoffen/476/
#
# ---------------------
# nio
# f/et5/13859/
# f/elektrisch/11756/
#
# ---------------------
# nissan
# f/qashqai/1033/
# f/micra/1020/
# f/juke/1043/
# f/leaf/1045/
# f/note/1025/
# f/x-trail/1027/
# f/benzine/473/
# f/diesel/474/
# f/elektrisch/11756/
# f/hybride-elektrisch-benzine/13838/
# f/lpg/475/
# f/overige-brandstoffen/476/
#
# ---------------------
# oldsmobile
# f/benzine/473/
# f/diesel/474/
# f/lpg/475/
#
# ---------------------
# oldtimers
# f/mercedes-benz/593/
# f/volkswagen/595/
# f/overige-merken/59/
# f/bmw/1050/
# f/volvo/1049/
# f/citroen/596/
# f/benzine/473/
# f/diesel/474/
# f/elektrisch/11756/
# f/lpg/475/
# f/overige-brandstoffen/476/
#
# ---------------------
# opel
# f/corsa/1065/
# f/astra/1064/
# f/meriva/1077/
# f/mokka/10773/
# f/zafira/1067/
# f/insignia/1080/
# f/benzine/473/
# f/diesel/474/
# f/elektrisch/11756/
# f/hybride-elektrisch-benzine/13838/
# f/lpg/475/
# f/cng-aardgas/13840/
# f/overige-brandstoffen/476/
#
# ---------------------
# peugeot
# f/208/10775/
# f/308/1099/
# f/2008/10776/
# f/3008/1105/
# f/207/1098/
# f/108/10923/
# f/benzine/473/
# f/diesel/474/
# f/elektrisch/11756/
# f/hybride-elektrisch-benzine/13838/
# f/hybride-elektrisch-diesel/13839/
# f/lpg/475/
# f/overige-brandstoffen/476/
#
# ---------------------
# polestar
# f/polestar-2/11920/
# f/polestar-1/11919/
#
# ---------------------
# pontiac
# f/overige-modellen/1113/
# f/firebird/1110/
# f/solstice/10785/
# f/g6/10783/
# f/grand-prix/1111/
# f/benzine/473/
# f/lpg/475/
# f/overige-brandstoffen/476/
#
# ---------------------
# porsche
# f/cayenne/1120/
# f/911/1114/
# f/panamera/1124/
# f/macan/10915/
# f/overige-modellen/1121/
# f/boxster/1119/
# f/benzine/473/
# f/diesel/474/
# f/elektrisch/11756/
# f/hybride-elektrisch-benzine/13838/
# f/lpg/475/
# f/overige-brandstoffen/476/
#
# ---------------------
# ram
# f/overige-modellen/13881/
# f/1500/13877/
# f/benzine/473/
# f/lpg/475/
#
# ---------------------
# renault
# f/clio/1125/
# f/megane/1127/
# f/captur/10890/
# f/twingo/1128/
# f/scenic/1133/
# f/grand-scenic/1139/
# f/benzine/473/
# f/diesel/474/
# f/elektrisch/11756/
# f/hybride-elektrisch-benzine/13838/
# f/hybride-elektrisch-diesel/13839/
# f/lpg/475/
# f/overige-brandstoffen/476/
#
# ---------------------
# rolls-royce
# f/silver-shadow/1150/
# f/wraith/11728/
# f/overige-modellen/1153/
# f/ghost/10794/
# f/silver-spur/1152/
# f/corniche/1146/
# f/benzine/473/
# f/lpg/475/
#
# ---------------------
# rover
# f/75/1155/
# f/overige-modellen/1158/
# f/25/1161/
# f/200-serie/1156/
# f/45/1154/
# f/800-serie/1162/
# f/benzine/473/
# f/diesel/474/
# f/lpg/475/
#
# ---------------------
# saab
# f/saab-9-3/1163/
# f/saab-9-5/1164/
# f/saab-900/1165/
# f/overige-modellen/1167/
# f/saab-9000/1166/
# f/saab-99/1170/
# f/benzine/473/
# f/diesel/474/
# f/elektrisch/11756/
# f/lpg/475/
# f/overige-brandstoffen/476/
#
# ---------------------
# seat
# f/ibiza/1172/
# f/leon/1173/
# f/arona/11743/
# f/ateca/11714/
# f/mii/10796/
# f/altea-xl/1182/
# f/benzine/473/
# f/diesel/474/
# f/elektrisch/11756/
# f/hybride-elektrisch-benzine/13838/
# f/lpg/475/
# f/cng-aardgas/13840/
# f/overige-brandstoffen/476/
#
# ---------------------
# seres
# f/overige-modellen/13905/
# f/benzine/473/
# f/elektrisch/11756/
#
# ---------------------
# skoda
# f/octavia/1185/
# f/fabia/1183/
# f/superb/1186/
# f/karoq/11744/
# f/citigo/10797/
# f/kodiaq/11715/
# f/benzine/473/
# f/diesel/474/
# f/elektrisch/11756/
# f/hybride-elektrisch-benzine/13838/
# f/lpg/475/
# f/cng-aardgas/13840/
# f/overige-brandstoffen/476/
#
# ---------------------
# smart
# f/forfour/1192/
# f/fortwo/1193/
# f/roadster/1194/
# f/city-coupe/1191/
# f/1/13893/
# f/overige-modellen/1195/
# f/benzine/473/
# f/diesel/474/
# f/elektrisch/11756/
#
# ---------------------
# spyker
# ---------------------
# ssangyong
# f/rexton/1200/
# f/korando/1197/
# f/kyron/1198/
# f/actyon/1196/
# f/tivoli/11725/
# f/musso/1199/
# f/benzine/473/
# f/diesel/474/
# f/elektrisch/11756/
# f/lpg/475/
#
# ---------------------
# subaru
# f/forester/1203/
# f/impreza/1204/
# f/legacy/1205/
# f/xv/10801/
# f/outback/1209/
# f/justy/1208/
# f/benzine/473/
# f/diesel/474/
# f/elektrisch/11756/
# f/hybride-elektrisch-benzine/13838/
# f/lpg/475/
#
# ---------------------
# suzuki
# f/swift/1215/
# f/alto/1213/
# f/vitara/1216/
# f/ignis/1217/
# f/sx4/1225/
# f/splash/1226/
# f/benzine/473/
# f/diesel/474/
# f/hybride-elektrisch-benzine/13838/
# f/lpg/475/
# f/overige-brandstoffen/476/
#
# ---------------------
# tesla
# f/model-s/11735/
# f/model-3/11736/
# f/model-x/11737/
# f/model-y/13853/
# f/elektrisch/11756/
# f/overige-brandstoffen/476/
#
# ---------------------
# toyota
# f/yaris/1232/
# f/aygo/1241/
# f/corolla/1230/
# f/auris/1239/
# f/rav4/1237/
# f/c-hr/11718/
# f/benzine/473/
# f/diesel/474/
# f/elektrisch/11756/
# f/hybride-elektrisch-benzine/13838/
# f/hybride-elektrisch-diesel/13839/
# f/lpg/475/
# f/waterstof/13841/
# f/overige-brandstoffen/476/
#
# ---------------------
# triumph
# f/overige-modellen/1258/
# f/spitfire/1254/
# f/tr6/1257/
# f/tr3/1255/
# f/tr4/1256/
# f/benzine/473/
#
# ---------------------
# vinfast
# ---------------------
# volkswagen
# f/golf/1260/
# f/polo/1262/
# f/tiguan/1275/
# f/up/10655/
# f/passat/1261/
# f/t-roc/11741/
# f/benzine/473/
# f/diesel/474/
# f/elektrisch/11756/
# f/hybride-elektrisch-benzine/13838/
# f/lpg/475/
# f/cng-aardgas/13840/
# f/overige-brandstoffen/476/
#
# ---------------------
# volvo
# f/v60/1302/
# f/xc60/1301/
# f/xc40/11900/
# f/v40/1282/
# f/v70/1283/
# f/xc90/1300/
# f/benzine/473/
# f/diesel/474/
# f/elektrisch/11756/
# f/hybride-elektrisch-benzine/13838/
# f/hybride-elektrisch-diesel/13839/
# f/lpg/475/
# f/cng-aardgas/13840/
# f/overige-brandstoffen/476/
#
# ---------------------
# vrachtwagens
# f/aanhangers-en-opleggers/10854/
# f/daf/1304/
# f/mercedes-benz/593/
# f/scania/1307/
# f/overige-merken/59/
# f/man/1313/
# f/benzine/473/
# f/diesel/474/
# f/elektrisch/11756/
# f/lpg/475/
# f/overige-brandstoffen/476/
#
# ---------------------
# xpeng
# ---------------------
# overige-auto-s
# f/benzine/473/
# f/diesel/474/
# f/elektrisch/11756/
# f/hybride-elektrisch-benzine/13838/
# f/lpg/475/
# f/overige-brandstoffen/476/
#
# ---------------------

# %%
models
# Out:
# {'Overige modellen': 'f/overige-modellen/1258/',
#  '500': 'f/500/767/',
#  'Altijd': '',
#  'U5': 'f/u5/13872/',
#  'U6': 'f/u6/13873/',
#  'Elektrisch': 'f/elektrisch/11756/',
#  'Diesel': 'f/diesel/474/',
#  'MiTo': 'f/mito/551/',
#  'Giulietta': 'f/giulietta/552/',
#  'Stelvio': 'f/stelvio/11651/',
#  '159': 'f/159/546/',
#  'Giulia': 'f/giulia/10900/',
#  '147': 'f/147/537/',
#  'Benzine': 'f/benzine/473/',
#  'Hybride Elektrisch/Benzine': 'f/hybride-elektrisch-benzine/13838/',
#  'LPG': 'f/lpg/475/',
#  'Overige brandstoffen': 'f/overige-brandstoffen/476/',
#  'B3': 'f/b3/11941/',
#  'B5': 'f/b5/11943/',
#  'B4': 'f/b4/11942/',
#  'B6': 'f/b6/11944/',
#  'B10': 'f/b10/11939/',
#  'D3': 'f/d3/11948/',
#  'DB9': 'f/db9/554/',
#  'V8 Vantage': 'f/v8-vantage/557/',
#  'DBS': 'f/dbs/555/',
#  'Rapide': 'f/rapide/556/',
#  'V12 Vanquish': 'f/v12-vanquish/10661/',
#  'A110': 'f/a110/11937/',
#  'A3': 'f/a3/560/',
#  'A4': 'f/a4/561/',
#  'A6': 'f/a6/562/',
#  'A1': 'f/a1/582/',
#  'A5': 'f/a5/570/',
#  'Q3': 'f/q3/10664/',
#  'Hybride Elektrisch/Diesel': 'f/hybride-elektrisch-diesel/13839/',
#  'CNG ': 'f/cng-aardgas/13840/',
#  'Continental': 'f/continental/933/',
#  'Continental GTC': 'f/continental-gtc/11722/',
#  'Bentayga': 'f/bentayga/11721/',
#  'Flying Spur': 'f/flying-spur/11723/',
#  'Arnage': 'f/arnage/585/',
#  'Mulsanne': 'f/mulsanne/590/',
#  'Volkswagen': 'f/volkswagen/595/',
#  'Mercedes-Benz': 'f/mercedes-benz/593/',
#  'Ford': 'f/ford/592/',
#  'Renault': 'f/renault/594/',
#  'Opel': 'f/opel/599/',
#  'Peugeot': 'f/peugeot/600/',
#  '3-Serie': 'f/3-serie/610/',
#  '5-Serie': 'f/5-serie/611/',
#  '1-Serie': 'f/1-serie/613/',
#  'X5': 'f/x5/618/',
#  'X1': 'f/x1/622/',
#  'X3': 'f/x3/617/',
#  'Enclave': 'f/enclave/10807/',
#  'Regal': 'f/regal/10810/',
#  'Riviera': 'f/riviera/10811/',
#  'Park Avenue': 'f/park-avenue/10809/',
#  'Skylark': 'f/skylark/10812/',
#  'HAN': 'f/han/13855/',
#  'TANG': 'f/tang/13856/',
#  'CTS': 'f/cts/624/',
#  'Escalade': 'f/escalade/627/',
#  'SRX': 'f/srx/629/',
#  'STS': 'f/sts/630/',
#  'Eldorado': 'f/eldorado/625/',
#  'Spark': 'f/spark/657/',
#  'Matiz': 'f/matiz/702/',
#  'Aveo': 'f/aveo/645/',
#  'Corvette': 'f/corvette/636/',
#  'Kalos': 'f/kalos/706/',
#  'PT Cruiser': 'f/pt-cruiser/661/',
#  'Grand Voyager': 'f/grand-voyager/669/',
#  'Voyager': 'f/voyager/663/',
#  'Pacifica': 'f/pacifica/670/',
#  'Crossfire': 'f/crossfire/667/',
#  '300C': 'f/300c/665/',
#  'C3': 'f/c3/679/',
#  'C1': 'f/c1/685/',
#  'C5': 'f/c5/673/',
#  'C4 ': 'f/c4-grand-picasso/687/',
#  'C4': 'f/c4/680/',
#  'C4 Cactus': 'f/c4-cactus/10925/',
#  'Formentor': 'f/formentor/13228/',
#  'Leon': 'f/leon/1173/',
#  'Born': 'f/born/13810/',
#  'Ateca': 'f/ateca/11714/',
#  'Sandero': 'f/sandero/699/',
#  'Duster': 'f/duster/696/',
#  'Logan MCV': 'f/logan-mcv/698/',
#  'Sandero Stepway': 'f/sandero-stepway/10687/',
#  'Spring': 'f/spring/13912/',
#  'Lodgy': 'f/lodgy/10686/',
#  'Tacuma': 'f/tacuma/709/',
#  'Lanos': 'f/lanos/701/',
#  'Nubira': 'f/nubira/704/',
#  'Lacetti': 'f/lacetti/707/',
#  'Cuore': 'f/cuore/713/',
#  'Sirion': 'f/sirion/715/',
#  'Terios': 'f/terios/722/',
#  'YRV': 'f/yrv/724/',
#  'Materia': 'f/materia/720/',
#  'Trevis': 'f/trevis/726/',
#  'RAM1500': 'f/ram1500/735/',
#  'RAM': 'f/ram/733/',
#  'Caliber': 'f/caliber/727/',
#  'Challenger': 'f/challenger/10688/',
#  'Charger': 'f/charger/728/',
#  'DS 3': 'f/ds-3/11814/',
#  'DS 7': 'f/ds-7/11817/',
#  'DS 4': 'f/ds-4/11815/',
#  'DS 9': 'f/ds-9/13913/',
#  'DS 5': 'f/ds-5/11816/',
#  'California': 'f/california/751/',
#  '360': 'f/360/746/',
#  '458': 'f/458/10709/',
#  'F430': 'f/f430/753/',
#  '599': 'f/599/750/',
#  'Panda': 'f/panda/758/',
#  '500C': 'f/500c/11667/',
#  'Punto': 'f/punto/759/',
#  'Punto EVO': 'f/punto-evo/779/',
#  'Grande Punto': 'f/grande-punto/772/',
#  'Focus': 'f/focus/784/',
#  'Fiësta': 'f/fiesta/783/',
#  'Ka': 'f/ka/788/',
#  'Kuga': 'f/kuga/794/',
#  'C-Max': 'f/c-max/793/',
#  'Mondeo': 'f/mondeo/785/',
#  'F-150': 'f/f-150/802/',
#  'Mustang': 'f/mustang/805/',
#  'Explorer': 'f/explorer/801/',
#  'F-250': 'f/f-250/803/',
#  'F-350': 'f/f-350/804/',
#  'Civic': 'f/civic/811/',
#  'Jazz': 'f/jazz/819/',
#  'CR-V': 'f/cr-v/816/',
#  'HR-V': 'f/hr-v/818/',
#  'Accord': 'f/accord/810/',
#  'Insight': 'f/insight/822/',
#  'H2': 'f/h2/830/',
#  'H3': 'f/h3/831/',
#  'H1': 'f/h1/829/',
#  'Tucson': 'f/tucson/850/',
#  'i10': 'f/i10/844/',
#  'Kona': 'f/kona/11901/',
#  'i20': 'f/i20/851/',
#  'i30': 'f/i30/845/',
#  'iX35': 'f/ix35/852/',
#  'Waterstof': 'f/waterstof/13841/',
#  'Q30': 'f/q30/11729/',
#  'FX-serie': 'f/fx-serie/858/',
#  'Q50': 'f/q50/10909/',
#  'M-serie': 'f/m-serie/860/',
#  'G-serie': 'f/g-serie/859/',
#  'D-Max': 'f/d-max/13800/',
#  'I-PACE': 'f/i-pace/11870/',
#  'XJ': 'f/xj/865/',
#  'XF': 'f/xf/864/',
#  'XK': 'f/xk/867/',
#  'S-Type': 'f/s-type/863/',
#  'F-Pace': 'f/f-pace/11677/',
#  'Compass': 'f/compass/876/',
#  'Wrangler': 'f/wrangler/874/',
#  'Renegade': 'f/renegade/10921/',
#  'Cherokee': 'f/cherokee/872/',
#  'Grand Cherokee': 'f/grand-cherokee/873/',
#  'Picanto': 'f/picanto/887/',
#  '': 'f/pro-cee-d/883/',
#  'Niro': 'f/niro/11678/',
#  'Sportage': 'f/sportage/892/',
#  'Rio': 'f/rio/889/',
#  'Stonic': 'f/stonic/11681/',
#  'Niva': 'f/niva/904/',
#  '2104': 'f/2104/10779/',
#  'Kalina': 'f/kalina/903/',
#  'Urus': 'f/urus/11907/',
#  'Huracan': 'f/huracan/11682/',
#  'Gallardo': 'f/gallardo/10828/',
#  'Aventador': 'f/aventador/10825/',
#  'Diablo': 'f/diablo/10827/',
#  'Ypsilon': 'f/ypsilon/914/',
#  'Delta': 'f/delta/908/',
#  'Musa': 'f/musa/911/',
#  'Thema': 'f/thema/916/',
#  'Thesis': 'f/thesis/913/',
#  'Range Rover ': 'f/range-rover-sport/924/',
#  'Range Rover Evoque': 'f/range-rover-evoque/10737/',
#  'Range Rover': 'f/range-rover/922/',
#  'Defender': 'f/defender/919/',
#  'Range Rover Velar': 'f/range-rover-velar/11683/',
#  'Discovery Sport': 'f/discovery-sport/11588/',
#  'CT-H': 'f/ct-h/932/',
#  'RX': 'f/rx-h/929/',
#  'IS': 'f/is/927/',
#  'NX': 'f/nx/11589/',
#  'UX': 'f/ux/11902/',
#  'GS': 'f/gs-h/926/',
#  'Town Car': 'f/town-car/935/',
#  'Navigator': 'f/navigator/934/',
#  'Aviator': 'f/aviator/10740/',
#  'Mark': 'f/mark/10742/',
#  'Elise': 'f/elise/10817/',
#  'Elan': 'f/elan/10816/',
#  'Europa': 'f/europa/10820/',
#  'Super Seven': 'f/super-seven/10823/',
#  '01': 'f/01/13767/',
#  'Quattroporte': 'f/quattroporte/940/',
#  'Ghibli': 'f/ghibli/938/',
#  'Levante': 'f/levante/11686/',
#  'Granturismo': 'f/granturismo/939/',
#  'Coupe': 'f/coupe/937/',
#  'CX-5': 'f/cx-5/10750/',
#  '2': 'f/2/952/',
#  '3': 'f/3/946/',
#  'CX-3': 'f/cx-3/11599/',
#  'MX-5': 'f/mx-5/945/',
#  '6': 'f/6/947/',
#  'GT': 'f/gt/11931/',
#  '570S': 'f/570s/11925/',
#  '650S': 'f/650s/11927/',
#  '540C': 'f/540c/11923/',
#  '570GT': 'f/570gt/11924/',
#  '720S': 'f/720s/11929/',
#  'C-Klasse': 'f/c-klasse/965/',
#  'A-Klasse': 'f/a-klasse/964/',
#  'E-Klasse': 'f/e-klasse/966/',
#  'CLA': 'f/cla/10886/',
#  'B-Klasse': 'f/b-klasse/973/',
#  'GLC': 'f/glc/11690/',
#  'Capri': 'f/capri/10834/',
#  'Grand Marquis': 'f/grand-marquis/10835/',
#  'ZS': 'f/zs/991/',
#  'EHS': 'f/ehs/13805/',
#  'MG4': 'f/mg4/13830/',
#  'MG5': 'f/mg5/13803/',
#  'B': 'f/b/983/',
#  'F': 'f/f/985/',
#  'Cooper': 'f/cooper/995/',
#  'Countryman': 'f/countryman/1001/',
#  'Clubman': 'f/clubman/1000/',
#  'One': 'f/one/997/',
#  'Cabrio': 'f/cabrio/999/',
#  'Cooper S': 'f/cooper-s/13787/',
#  'Outlander': 'f/outlander/1013/',
#  'Space Star': 'f/space-star/1005/',
#  'Colt': 'f/colt/1003/',
#  'ASX': 'f/asx/1016/',
#  'Eclipse Cross': 'f/eclipse-cross/11966/',
#  'Grandis': 'f/grandis/1012/',
#  'ET5': 'f/et5/13859/',
#  'Qashqai': 'f/qashqai/1033/',
#  'Micra': 'f/micra/1020/',
#  'Juke': 'f/juke/1043/',
#  'Leaf': 'f/leaf/1045/',
#  'Note': 'f/note/1025/',
#  'X-Trail': 'f/x-trail/1027/',
#  'Overige merken': 'f/overige-merken/59/',
#  'BMW': 'f/bmw/1050/',
#  'Volvo': 'f/volvo/1049/',
#  'Citroën': 'f/citroen/596/',
#  'Corsa': 'f/corsa/1065/',
#  'Astra': 'f/astra/1064/',
#  'Meriva': 'f/meriva/1077/',
#  'Mokka': 'f/mokka/10773/',
#  'Zafira': 'f/zafira/1067/',
#  'Insignia': 'f/insignia/1080/',
#  '208': 'f/208/10775/',
#  '308': 'f/308/1099/',
#  '2008': 'f/2008/10776/',
#  '3008': 'f/3008/1105/',
#  '207': 'f/207/1098/',
#  '108': 'f/108/10923/',
#  'Polestar 2': 'f/polestar-2/11920/',
#  'Polestar 1': 'f/polestar-1/11919/',
#  'Firebird': 'f/firebird/1110/',
#  'Solstice': 'f/solstice/10785/',
#  'G6': 'f/g6/10783/',
#  'Grand Prix': 'f/grand-prix/1111/',
#  'Cayenne': 'f/cayenne/1120/',
#  '911': 'f/911/1114/',
#  'Panamera': 'f/panamera/1124/',
#  'Macan': 'f/macan/10915/',
#  'Boxster': 'f/boxster/1119/',
#  '1500': 'f/1500/13877/',
#  'Clio': 'f/clio/1125/',
#  'Mégane': 'f/megane/1127/',
#  'Captur': 'f/captur/10890/',
#  'Twingo': 'f/twingo/1128/',
#  'Scénic': 'f/scenic/1133/',
#  'Grand Scenic': 'f/grand-scenic/1139/',
#  'Silver Shadow': 'f/silver-shadow/1150/',
#  'Wraith': 'f/wraith/11728/',
#  'Ghost': 'f/ghost/10794/',
#  'Silver Spur': 'f/silver-spur/1152/',
#  'Corniche': 'f/corniche/1146/',
#  '75': 'f/75/1155/',
#  '25': 'f/25/1161/',
#  '200-Serie': 'f/200-serie/1156/',
#  '45': 'f/45/1154/',
#  '800-Serie': 'f/800-serie/1162/',
#  'Saab 9-3': 'f/saab-9-3/1163/',
#  'Saab 9-5': 'f/saab-9-5/1164/',
#  'Saab 900': 'f/saab-900/1165/',
#  'Saab 9000': 'f/saab-9000/1166/',
#  'Saab 99': 'f/saab-99/1170/',
#  'Ibiza': 'f/ibiza/1172/',
#  'Arona': 'f/arona/11743/',
#  'Mii': 'f/mii/10796/',
#  'Altea XL': 'f/altea-xl/1182/',
#  'Octavia': 'f/octavia/1185/',
#  'Fabia': 'f/fabia/1183/',
#  'Superb': 'f/superb/1186/',
#  'Karoq': 'f/karoq/11744/',
#  'Citigo': 'f/citigo/10797/',
#  'Kodiaq': 'f/kodiaq/11715/',
#  'ForFour': 'f/forfour/1192/',
#  'ForTwo': 'f/fortwo/1193/',
#  'Roadster': 'f/roadster/1194/',
#  'City-Coupe': 'f/city-coupe/1191/',
#  '#1': 'f/1/13893/',
#  'Rexton': 'f/rexton/1200/',
#  'Korando': 'f/korando/1197/',
#  'Kyron': 'f/kyron/1198/',
#  'Actyon': 'f/actyon/1196/',
#  'Tivoli': 'f/tivoli/11725/',
#  'Musso': 'f/musso/1199/',
#  'Forester': 'f/forester/1203/',
#  'Impreza': 'f/impreza/1204/',
#  'Legacy': 'f/legacy/1205/',
#  'XV': 'f/xv/10801/',
#  'Outback': 'f/outback/1209/',
#  'Justy': 'f/justy/1208/',
#  'Swift': 'f/swift/1215/',
#  'Alto': 'f/alto/1213/',
#  'Vitara': 'f/vitara/1216/',
#  'Ignis': 'f/ignis/1217/',
#  'SX4': 'f/sx4/1225/',
#  'Splash': 'f/splash/1226/',
#  'Model S': 'f/model-s/11735/',
#  'Model 3': 'f/model-3/11736/',
#  'Model X': 'f/model-x/11737/',
#  'Model Y': 'f/model-y/13853/',
#  'Yaris': 'f/yaris/1232/',
#  'Aygo': 'f/aygo/1241/',
#  'Corolla': 'f/corolla/1230/',
#  'Auris': 'f/auris/1239/',
#  'Rav4': 'f/rav4/1237/',
#  'C-HR': 'f/c-hr/11718/',
#  'Spitfire': 'f/spitfire/1254/',
#  'TR6': 'f/tr6/1257/',
#  'TR3': 'f/tr3/1255/',
#  'TR4': 'f/tr4/1256/',
#  'Golf': 'f/golf/1260/',
#  'Polo': 'f/polo/1262/',
#  'Tiguan': 'f/tiguan/1275/',
#  'up!': 'f/up/10655/',
#  'Passat': 'f/passat/1261/',
#  'T-Roc': 'f/t-roc/11741/',
#  'V60': 'f/v60/1302/',
#  'XC60': 'f/xc60/1301/',
#  'XC40': 'f/xc40/11900/',
#  'V40': 'f/v40/1282/',
#  'V70': 'f/v70/1283/',
#  'XC90': 'f/xc90/1300/',
#  'Aanhangers en Opleggers': 'f/aanhangers-en-opleggers/10854/',
#  'DAF': 'f/daf/1304/',
#  'Scania': 'f/scania/1307/',
#  'MAN': 'f/man/1313/'}

# %%
url = 'https://www.marktplaats.nl/l/auto-s/'
response = requests.get(url)

# %%
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.text, 'html.parser')

    # Replace 'your_element' with the HTML element containing the data you want to scrape
    # For example, if you want to scrape titles inside <h2> tags, use soup.find_all('h2')
    titles = soup.find_all('h2')

    # Extract and print the text content of each title
    for title in titles:
        print(title.text)
else:
    print(f"Failed to retrieve the page. Status code: {response.status_code}")
# Out:
# Marktplaats App
# ​Ga jij voor een occasion?
# Op zoek naar jouw perfecte auto
# Zo sluit je de deal
# Goed verzekerd de weg op

# %%
cars = soup.find('div', class_='hz-Tree-list-item')

# %%
car = soup.find_all('li',class_ = 'hz-Level-two')

# %%
for name in range(len(car)-1):
    print(car[name].text.split('(')[0])
# Out:
# Bestelauto's
# Volkswagen
# Mercedes-Benz
# BMW
# Audi
# Peugeot
# Opel
# Ford
# Renault
# Toyota
# Volvo
# Kia
# Citroën
# Fiat
# Hyundai
# Seat
# Mini
# Nissan
# Oldtimers
# Skoda
# Suzuki
# Mazda
# Land Rover
# Vrachtwagens
# Porsche
# Mitsubishi
# Alfa Romeo
# Chevrolet
# Lexus
# Honda
# Jaguar
# Dacia
# Tesla
# Dodge
# Jeep
# Saab
# MG
# Daihatsu
# Smart
# Lynk & Co
# Subaru
# Overige Auto's
# Chrysler
# Cupra
# DS
# Ford Usa
# Lancia
# Maserati
# Bentley
# Cadillac
# Daewoo
# Polestar
# Abarth
# Ferrari
# Rover
# Aston Martin
# Pontiac
# Lamborghini
# Lincoln
# Alpina
# SsangYong
# Infiniti
# Triumph
# Aiways
# Rolls-Royce
# Isuzu
# Hummer
# Aixam
# Alpine
# Buick
# Austin
# Oldsmobile
# Lada
# McLaren
# Mercury
# BYD
# Lotus
# RAM
# Fisker
# Landwind
# Seres
# NIO

# %%
href_value = car[11].a.get('href', 'No href attribute found')
print(href_value)
# Out:
# No href attribute found
